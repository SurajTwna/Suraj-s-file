# %%
import matplotlib.pyplot as plt
import numpy as np
import math as mt

def main():
    user = input("Do you want to see Math_Functions, Area, or Graph? ") #This is the main fucntion that pops up to let the user pick what function they want and basically the code runs under this code

    print("Choose from Math_Functions, Area, Graph.")

    if user.lower() == "math_functions": #If the user pick the math functions then it puts it into this block with the basic math functions and it shows functions like add, subtract and etc
        choice_1 = input("Pick from addition, subtraction, multiplication, and division: ")

        x = input("Type a number: ") #I defined x and y so that I use these for the basic math fucntions
        y = input("Type another number: ")

        if choice_1.lower() == "addition":
            add = float(x) + float(y)
            print(f"The answer is {add}")

        elif choice_1.lower() == "multiplication":
            multiplication = float(x) * float(y)
            print(f"The answer is {multiplication}")

        elif choice_1.lower() == "subtraction":
            subtraction = float(x) - float(y)
            print(f"The answer is {subtraction}")

        elif choice_1.lower() == "division":
            division = float(x) / float(y)
            print(f"The answer is {division}")

    elif user.lower() == "area": #If the user pick the Graph then it puts it into this block with the basic math functions and it shows functions like area of triangle, area of cirlce and etc
        choice_2 = input("Pick from area of: square, rectangle, triangle, and circle: ")

        if choice_2.lower() == "rectangle":
            l = int(input("Enter rectangle's length: ")) #here i defined lentgh and with since i need them for the area of the cirle
            w = int(input("Enter rectangle's width: "))
            rect_area = l * w
            print(f"The area of the rectangle is {rect_area}.")

        elif choice_2.lower() == "square":
            s = int(input("Enter square's side length: ")) #here I defined side lengths since i need it for the math
            sqt_area = s * s
            print(f"The area of the square is {sqt_area}.")

        elif choice_2.lower() == "triangle": #Here i defined base and hight of the triangle, then for my acctual definition for the equation I put B*H / 2 since that is how you get the area
            h = int(input("Enter triangle's height length: "))
            b = int(input("Enter triangle's base length: "))
            tri_area = 0.5 * b * h
            print(f"The area of the triangle is {tri_area}.")

        elif choice_2.lower() == "circle":
            r = int(input("Enter circle's radius length: ")) #here I defined radius and pi for the area of circle, the for my function I did pi *r*r since area ofr circle is piR^2
            pi = 3.14
            circ_area = pi * r * r
            print(f"The area of the circle is {circ_area}.")

    elif user.lower() == "graph": #Here it says if the user types in graph it shows the graph functions
        choice_3 = input("Pick from types of graphs: polynomial, sin, cos, tan: ")

        if choice_3.lower() == "polynomial": #here it says if choice3 is polynomial it places the polynomial equation
            try:
                polynomial_equation = input("Type in an equation using the 'x' variable: ")
                x = np.linspace(-10, 10, 400) #I defined my x value
                y = eval(polynomial_equation)#I put my y value as evaluating the polynomial equation

                plt.plot(x, y)
                plt.title(f"Equation: {polynomial_equation}") #Here the title shows the polynomial equation as the title
                plt.xlabel('x')
                plt.ylabel('y')
                plt.grid(True)
                plt.show()

                choice = ("do you want a linear equation (yes or no)?") #This asks user for linear equation and I got this part from online but I understand it (chatgpt)

                if choice.lower() == 'yes': #if user wnats a linear line then it then defines the slope, and y intercept of the linear line
                  m = float(input("Give a slope for the line"))
                  c = float(input("Give a y int for your line"))
                  y_lin = (m)*(x) + (c) #here i put all the defined values into an equation that is the linear line
                  plt.plot(x,y_lin)

                  if 'a' in locals() and 'a' != 0: # This code sees if a is not 0 and if it is met it calculates the x poi and y poi then it scatters the graph
                    x_poi = (c -b) / (2*a)
                    y_poi = a*x_poi**2 + b*x_poi + c
                    plt.scatter(x_poi, y_poi, color='purple', label= 'P.O.I')
                    print("P.O.I is :", (x_poi, y_poi))

                  else:
                    print("No POI")


            except:
                print(f"Error has occurred. Restart:")

        elif choice_3.lower() == "sin": #If user wants sin graphs it prints the sin graph by using the y value that are create dusing the np.sin function
            x = np.linspace(-3 * np.pi, 3 * np.pi, 100)
            y = np.sin(x)
            plt.grid(True)
            plt.title('Sine Graph')
            plt.plot(x, y)
            plt.show()

        elif choice_3.lower() == "tan": #If user wants sin graphs it prints the tan graph by using the y value that are create dusing the np.tan function
            x = np.linspace(-3 * np.pi, 3 * np.pi, 100)
            y = np.tan(x)
            plt.grid(True)
            plt.title('Tan Graph')
            plt.plot(x, y)
            plt.ylim(-4, 4)
            plt.show()

        elif choice_3.lower() == "cos": #if user wants a cos graph it calulates the y value using np.cos funciton
            x = np.linspace(-3 * np.pi, 3 * np.pi, 100)
            y = np.cos(x)
            plt.grid(True)
            plt.title('Cos Graph')
            plt.plot(x, y)
            plt.show()

if __name__ == "__main__": #This ensures that the main function is shown when the code is ran
    main()
# Out:
# Do you want to see Math_Functions, Area, or Graph? Graph
# Choose from Math_Functions, Area, Graph.
# Pick from types of graphs: polynomial, sin, cos, tan: polynomial
# Type in an equation using the 'x' variable: 3*x**2 + 4*x + 6
